# %%
import numpy as np

rating = np.array([
    [1, 280, 892, 621],
    [2, 254, 742, 763],
    [3, 352, 820, 757],
    [4, 189, 730, 614],
    [5, 209, 758, 608],
    [6, 312, 652, 545],
    [7, 199, 680, 553],
    [8, 224, 592, 485],
    [9, 293, 603, 466],
    [10, 187, 507, 423]
])

# %%
mean = np.mean(rating[:, -1])
mean
# Out:
# 583.5

# %%
median = np.median(rating[:, -1])
median
# Out:
# 580.5

# %%
mean_col2 = np.mean(rating[:, 1])
mean_col2
# Out:
# 249.9

# %%
std_col2 = np.std(rating[:, 1])
std_col2
# Out:
# 54.46182148992081

# %%
corr = np.corrcoef(rating[:, 1], rating[:, 2])
corr
# Out:
# array([[1.        , 0.38492604],
#        [0.38492604, 1.        ]])

# %%
Графики табличного типа

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('restaurant.csv')

tips = df[['total_bill', 'tip', 'size']]

correlation=tips.corr()


sns.heatmap(correlation, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
Распределение данных

# %%
sns.boxplot(x='day', y='tip', data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day', y='tip', data=df, hue='vegan')
# Out:
# <Axes: xlabel='day', ylabel='tip'>
